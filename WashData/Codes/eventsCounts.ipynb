# %%
import pandas as pd
df = pd.read_csv('../Source/summerOly_athletes.csv')

# %%
df = df[df['Year'] == 2024]
df['Event'] = df['Event']+df['Sport']
df_unique = df.drop_duplicates(subset='Event')
df_unique
# Out:
#                       Name Sex           Team  NOC  Year   City
# 237673    Artur Aleksanyan   M        Armenia  ARM  2024  Paris  \
# 237674      Malkhas Amoyan   M        Armenia  ARM  2024  Paris
# 237675     Slavik Galstyan   M        Armenia  ARM  2024  Paris
# 237676   Arsen Harutyunyan   M        Armenia  ARM  2024  Paris
# 237677     Vazgen Tevanyan   M        Armenia  ARM  2024  Paris
# ...                    ...  ..            ...  ...   ...    ...
# 246481        Taylor Knibb   F  United States  USA  2024  Paris
# 247006        Katie Grimes   F  United States  USA  2024  Paris
# 247411          Amy Atwell   F      Australia  AUS  2024  Paris
# 249008     Guilherme Costa   M         Brazil  BRA  2024  Paris
# 251812  Sylvain Fridelance   M    Switzerland  SUI  2024  Paris
#
#                               Sport
# 237673                    Wrestling  \
# 237674                    Wrestling
# 237675                    Wrestling
# 237676                    Wrestling
# ...
